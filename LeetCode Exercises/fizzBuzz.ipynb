# %%
def fizzBuzzRazzJazzFuzz(n):
    a = []
    for i in range(1, n + 1):
        if i % 15015 == 0:
            a.append("FizzBuzzRazzJazzFuzz")
        elif i % 5005 == 0:
            a.append("BuzzRazzJazzFuzz")
        elif i % 3003 == 0:
            a.append("FizzRazzJazzFuzz")
        elif i % 2145 == 0:
            a.append("FizzBuzzJazzFuzz")
        elif i % 1365 == 0:
            a.append("FizzBuzzRazzFuzz")
        elif i % 1001 == 0:
            a.append("RazzJazzFuzz")
        elif i % 715 == 0:
            a.append("BuzzJazzFuzz")
        elif i % 455 == 0:
            a.append("BuzzRazzFuzz")
        elif i % 429 == 0:
            a.append("FizzJazzFuzz")
        elif i % 385 == 0:
            a.append("BuzzRazzJazz")
        elif i % 273 == 0:
            a.append("FizzRazzFuzz")
        elif i % 231 == 0:
            a.append("FizzRazzJazz")
        elif i % 195 == 0:
            a.append("FizzBuzzFuzz")
        elif i % 165 == 0:
            a.append("FizzBuzzJazz")
        elif i % 143 == 0:
            a.append("JazzFuzz")
        elif i % 105 == 0:
            a.append("FizzBuzzRazz")
        elif i % 91 == 0:
            a.append("RazzFuzz")
        elif i % 77 == 0:
            a.append("RazzJazz")
        elif i % 65 == 0:
            a.append("BuzzFuzz")
        elif i % 55 == 0:
            a.append("BuzzJazz")
        elif i % 39 == 0:
            a.append("FizzFuzz")
        elif i % 35 == 0:
            a.append("BuzzRazz")
        elif i % 33 == 0:
            a.append("FizzJazz")
        elif i % 21 == 0:
            a.append("FizzRazz")
        elif i % 15 == 0:
            a.append("FizzBuzz")
        elif i % 13 == 0:
            a.append("Fuzz")
        elif i % 11 == 0:
            a.append("Jazz")
        elif i % 7 == 0:
            a.append("Razz")
        elif i % 5 == 0:
            a.append("Buzz")
        elif i % 3 == 0:
            a.append("Fizz")
        else:
            a.append(str(i))
    return a


for i in fizzBuzzRazzJazzFuzz(65536):
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Razz
# 8
# Fizz
# Buzz
# Jazz
# Fizz
# Fuzz
# Razz
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# FizzRazz
# Jazz
# 23
# Fizz
# Buzz
# Fuzz
# Fizz
# Razz
# 29
# FizzBuzz
# 31
# 32
# FizzJazz
# 34
# BuzzRazz
# Fizz
# 37
# 38
# FizzFuzz
# Buzz
# 41
# FizzRazz
# 43
# Jazz
# FizzBuzz
# 46
# 47
# Fizz
# Razz
# Buzz
# Fizz
# Fuzz
# 53
# Fizz
# BuzzJazz
# Razz
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# FizzRazz
# 64
# BuzzFuzz
# FizzJazz
# 67
# 68
# Fizz
# BuzzRazz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# RazzJazz
# FizzFuzz
# 79
# Buzz
# Fizz
# 82
# 83
# FizzRazz
# Buzz
# 86
# Fizz
# Jazz
# 89
# FizzBuzz
# RazzFuzz
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# Razz
# FizzJazz
# Buzz
# 101
# Fizz
# 103
# Fuzz
# FizzBuzzRazz
# 106
# 107
# Fizz
# 109
# BuzzJazz
# Fizz
# Razz
# 113
# Fizz
# Buzz
# 116
# FizzFuzz
# 118
# Razz
# FizzBuzz
# Jazz
# 122
# Fizz
# 124
# Buzz
# FizzRazz
# 127
# 128
# Fizz
# BuzzFuzz
# 131
# FizzJazz
# Razz
# 134
# FizzBuzz
# 136
# 137
# Fizz
# 139
# ...
